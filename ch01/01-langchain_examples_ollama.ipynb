# %% [markdown]
# # Chapter 1

# %% [markdown]
# # LangChain examples with Ollama (Gemma 2)

# %% [markdown]
# ## Sentence completion example

# %%
from langchain_ollama import ChatOllama

# %%
# !pip install langchain_ollama
# Out:
# Collecting langchain_ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in ./env_ch01/lib/python3.12/site-packages (from langchain_ollama) (1.2.28)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain_ollama)
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.13.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./env_ch01/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./env_ch01/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./env_ch01/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.25.0)
# Requirement already satisfied: anyio in ./env_ch01/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (4.13.0)
# Requirement already satisfied: certifi in ./env_ch01/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./env_ch01/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.0.9)
# Requirement already satisfied: idna in ./env_ch01/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in ./env_ch01/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./env_ch01/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in ./env_ch01/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./env_ch01/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env_ch01/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./env_ch01/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.6.3)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama, langchain_ollama
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain_ollama]
# Successfully installed langchain_ollama-1.1.0 ollama-0.6.1

# %%
llm = ChatOllama(model="gemma4:e2b")
llm.invoke("It's a cold day, I would like to go to the...")
# Out:
# AIMessage(content="...where would you like to go?\n\nAre you looking for something:\n\n* **Cozy and warm** (like a café, bookstore, or museum)?\n* **Active and refreshing** (like a hike or an outdoor market)?\n* **Indoor and entertaining** (like an escape room or a movie)?\n* **A place to warm up** (like a cozy restaurant or a hot chocolate spot)?\n\nTell me what kind of mood you're in, and I can give you some ideas! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-14T00:12:35.184137753Z', 'done': True, 'done_reason': 'stop', 'total_duration': 51443371232, 'load_duration': 1364508799, 'prompt_eval_count': 31, 'prompt_eval_duration': 2098665468, 'eval_count': 434, 'eval_duration': 47026561536, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019d8954-68ab-7ce3-8b96-a077b78e0808-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 434, 'total_tokens': 465})

# %% [markdown]
# ## Simple prompt

# %%
prompt_input = """Write a short message to remind users to be 
vigilant about phishing attacks."""
response = llm.invoke(prompt_input)

print(response.content)
# Out:
# Here are a few options, depending on the tone and platform you are using:
#
# **Option 1: Short and Direct (Good for banners or alerts)**
# > **Phishing Alert: Stay Vigilant!** Always verify before clicking links or sharing personal information.
#
# **Option 2: Action-Oriented (Good for emails)**
# > Be cautious! Phishing attacks are constantly evolving. Double-check all suspicious emails and links before taking action.
#
# **Option 3: Brief and Punchy (Good for social media)**
# > 🚨 Phishing Warning: Be vigilant. Don't click suspicious links!
#
# **Option 4: Slightly More Formal (Good for security guidelines)**
# > Remember to be vigilant against phishing attacks. Verify the sender and scrutinize all unexpected requests before responding.

# %% [markdown]
# ## Prompt instantiated thorugh a PromptTemplate

# %%
from langchain_core.prompts import PromptTemplate

segovia_aqueduct_text = """The Aqueduct of Segovia 
(Spanish: Acueducto de Segovia) is a Roman aqueduct in Segovia, 
Spain. It was built around the first century AD to channel water 
from springs in the mountains 17 kilometres (11 mi) away to the 
city's fountains, public baths and private houses, and was in 
use until 1973. Its elevated section, with its complete arcade 
of 167 arches, is one of the best-preserved Roman aqueduct 
bridges and the foremost symbol of Segovia, as evidenced by 
its presence on the city's coat of arms. The Old Town of 
Segovia and the aqueduct, were declared a UNESCO World 
Heritage Site in 1985. As the aqueduct lacks a legible 
inscription (one was apparently located in the structure's 
attic, or top portion[citation needed]), the date of 
construction cannot be definitively determined. The general 
date of the Aqueduct's construction was long a mystery, 
although it was thought to have been during the 1st century AD, 
during the reigns of the Emperors Domitian, Nerva, and Trajan. 
At the end of the 20th century, Géza Alföldy deciphered the 
text on the dedication plaque by studying the anchors that held 
the now missing bronze letters in place. He determined that Emperor 
Domitian (AD 81–96) ordered its construction[1] and the year 98 AD
was proposed as the most likely date of completion.[2] However, 
in 2016 archeological evidence was published which points to a 
slightly later date, after 112 AD, during the government of 
Trajan or in the beginning of the government of emperor Hadrian, 
from 117 AD."""

prompt_template = PromptTemplate.from_template("""You are an 
experienced copywriter. Write a {num_words} words summary of 
the following text, using a {tone} tone: {text}""")

prompt_input = prompt_template.format(
    text=segovia_aqueduct_text, 
    num_words=20, 
    tone="knowledgeable and engaging")
response = llm.invoke(prompt_input)
print(response.content)

# %% [markdown]
# ## Chain example

# %%
prompt_template = PromptTemplate.from_template("You are an experienced copywriter. Write a {num_words} words summary of the following text, using a {tone} tone: {text}")
llm = ChatOllama(model="gemma2")

chain = prompt_template | llm

# %%
response = chain.invoke({"text": segovia_aqueduct_text, 
              "num_words": 20, 
              "tone": "knowledgeable and engaging"})
print(response.content)
